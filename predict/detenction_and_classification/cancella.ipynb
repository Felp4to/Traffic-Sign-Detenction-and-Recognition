# %%
import os

# %%
def delete_files_longer_than(folder_path, max_length):
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return

    # Elencare tutti i file nella cartella
    files = os.listdir(folder_path)

    # Iterare sui file e eliminare quelli con un nome più lungo della lunghezza massima
    for file_name in files:
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and len(file_name) > max_length:
            try:
                os.remove(file_path)
                print(f"Eliminato: {file_name}")
            except Exception as e:
                print(f"Errore durante l'eliminazione di {file_name}: {e}")

# %%
cartella1 = "C:/Users/Paolo/Desktop/Prova2/Traffic Sign Detenction/Traffic Sign Detenction/test/images"
cartella2 = "C:/Users/Paolo/Desktop/Prova2/Traffic Sign Detenction/Traffic Sign Detenction/test/labels"
lunghezza_massima = 10

# Esegui la funzione per eliminare i file
delete_files_longer_than(cartella1, lunghezza_massima)
delete_files_longer_than(cartella2, lunghezza_massima)
# Out:
# Eliminato: 0000016.jpg
# Eliminato: 0000020.jpg
# Eliminato: 0000023.jpg
# Eliminato: 0000033.jpg
# Eliminato: 0000040.jpg
# Eliminato: 0000053.jpg
# Eliminato: 0000064.jpg
# Eliminato: 0000070.jpg
# Eliminato: 0000071.jpg
# Eliminato: 0000072.jpg
# Eliminato: 0000079.jpg
# Eliminato: 0000101.jpg
# Eliminato: 0000120.jpg
# Eliminato: 0000124.jpg
# Eliminato: 0000128.jpg
# Eliminato: 0000130.jpg
# Eliminato: 0000148.jpg
# Eliminato: 0000154.jpg
# Eliminato: 0000156.jpg
# Eliminato: 0000166.jpg
# Eliminato: 0000191.jpg
# Eliminato: 0000196.jpg
# Eliminato: 0000198.jpg
# Eliminato: 0000213.jpg
# Eliminato: 0000238.jpg
# Eliminato: 0000256.jpg
# Eliminato: 0000259.jpg
# Eliminato: 0000274.jpg
# Eliminato: 0000275.jpg
# Eliminato: 0000281.jpg
# Eliminato: 0000286.jpg
# Eliminato: 0000299.jpg
# Eliminato: 0000302.jpg
# Eliminato: 0000304.jpg
# Eliminato: 0000307.jpg
# Eliminato: 0000310.jpg
# Eliminato: 0000315.jpg
# Eliminato: 0000335.jpg
# Eliminato: 0000337.jpg
# Eliminato: 0000340.jpg
# ...
